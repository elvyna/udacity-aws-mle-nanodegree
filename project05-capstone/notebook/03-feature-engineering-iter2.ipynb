# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import os

sns.set_context('talk')

# %%
input_train_path = os.path.join(
    '..',
    'dataset',
    'preprocessed',
    'transact_train.csv'
)

df_train = pd.read_csv(input_train_path)
df_train.head()
# Out:
#    sessionNo  startHour  startWeekday  duration  cCount  cMinPrice  cMaxPrice  \
# 0          1        6.0           5.0     0.000     1.0      59.99      59.99
# 1          1        6.0           5.0    11.940     1.0      59.99      59.99
# 2          1        6.0           5.0    39.887     1.0      59.99      59.99
# 3          2        6.0           5.0     0.000     0.0     -99.00     -99.00
# 4          2        6.0           5.0    15.633     0.0     -99.00     -99.00
#
#    cSumPrice  bCount  bMinPrice  ...  bMinPrice_is_outlier  \
# 0      59.99     1.0      59.99  ...                     0
# 1      59.99     1.0      59.99  ...                     0
# 2      59.99     1.0      59.99  ...                     0
# 3     -99.00     0.0     -99.00  ...                     1
# 4     -99.00     0.0     -99.00  ...                     1
#
#    bMaxPrice_is_outlier  bSumPrice_is_outlier  bStep_is_outlier  \
# 0                     0                     0                 0
# 1                     0                     0                 0
# 2                     0                     0                 0
# 3                     1                     0                 0
# 4                     1                     0                 0
#
#   maxVal_is_outlier  customerScore_is_outlier  accountLifetime_is_outlier  \
# 0                 0                         0                           0
# 1                 0                         0                           0
# 2                 0                         0                           0
# 3                 0                         0                           0
# 4                 0                         0                           0
#
#    payments_is_outlier  age_is_outlier  lastOrder_is_outlier
# 0                    0               0                     0
# 1                    0               0                     0
# 2                    0               0                     0
# 3                    0               0                     0
# 4                    0               0                     0
#
# [5 rows x 42 columns]

# %%
df_train.iloc[0]
# Out:
# sessionNo                         1
# startHour                       6.0
# startWeekday                    5.0
# duration                        0.0
# cCount                          1.0
# cMinPrice                     59.99
# cMaxPrice                     59.99
# cSumPrice                     59.99
# bCount                          1.0
# bMinPrice                     59.99
# bMaxPrice                     59.99
# bSumPrice                     59.99
# bStep                         -99.0
# onlineStatus                    -99
# availability                    -99
# customerNo                      1.0
# maxVal                        600.0
# customerScore                  70.0
# accountLifetime                21.0
# payments                        1.0
# age                            43.0
# address                           1
# lastOrder                      49.0
# order                             1
# startHour_is_outlier              0
# startWeekday_is_outlier           0
# duration_is_outlier               0
# cCount_is_outlier                 0
# cMinPrice_is_outlier              0
# cMaxPrice_is_outlier              0
# cSumPrice_is_outlier              0
# bCount_is_outlier                 0
# bMinPrice_is_outlier              0
# bMaxPrice_is_outlier              0
# bSumPrice_is_outlier              0
# bStep_is_outlier                  0
# maxVal_is_outlier                 0
# customerScore_is_outlier          0
# accountLifetime_is_outlier        0
# payments_is_outlier               0
# age_is_outlier                    0
# lastOrder_is_outlier              0
# Name: 0, dtype: object

# %%
## create categorical values based on startHour
condition_list = [
    ((df_train['startHour'] >= 0) & (df_train['startHour'] < 6)),
    ((df_train['startHour'] >= 6) & (df_train['startHour'] < 12)),
    ((df_train['startHour'] >= 12) & (df_train['startHour'] < 18)),
    ((df_train['startHour'] >= 18) & (df_train['startHour'] < 25)),
]

choice_list = [
    "early_morning",
    "morning",
    "afternoon",
    "evening"
]

df_train["time_of_day"] = np.select(condition_list, choice_list, default="unknown")

# %%
## use one hot encoder for categorical values
from sklearn.preprocessing import OneHotEncoder

selected_feature_list = ['availability','address','time_of_day','onlineStatus']
for selected_feature in selected_feature_list:
    ohe = OneHotEncoder()
    feature_array = np.array(df_train[selected_feature])
    feature_encoded = ohe.fit_transform(np.reshape(feature_array, (-1,1))).toarray()

    try:
        feature_encoded = pd.DataFrame(
            data = feature_encoded, 
            columns = [selected_feature + '_' + col.str.replace(' ','_') for col in ohe.categories_[0]]
        )
    except:
        print(selected_feature)
        feature_encoded = pd.DataFrame(
            data = feature_encoded, 
            columns = [selected_feature + '_' + str(col).replace(' ','_') for col in ohe.categories_[0]]
        )
        
    feature_encoded.drop(
        feature_encoded.columns[-1], 
        axis = 1,
        inplace = True
    )

    df_train = pd.concat([df_train, feature_encoded], axis = 1)
# Out:
# availability
# address
# time_of_day
# onlineStatus

# %%
df_train.iloc[0]
# Out:
# sessionNo                                         1
# startHour                                       6.0
# startWeekday                                    5.0
# duration                                        0.0
# cCount                                          1.0
# cMinPrice                                     59.99
# cMaxPrice                                     59.99
# cSumPrice                                     59.99
# bCount                                          1.0
# bMinPrice                                     59.99
# bMaxPrice                                     59.99
# bSumPrice                                     59.99
# bStep                                         -99.0
# onlineStatus                                    -99
# availability                                    -99
# customerNo                                      1.0
# maxVal                                        600.0
# customerScore                                  70.0
# accountLifetime                                21.0
# payments                                        1.0
# age                                            43.0
# address                                           1
# lastOrder                                      49.0
# order                                             1
# startHour_is_outlier                              0
# startWeekday_is_outlier                           0
# duration_is_outlier                               0
# cCount_is_outlier                                 0
# cMinPrice_is_outlier                              0
# cMaxPrice_is_outlier                              0
# cSumPrice_is_outlier                              0
# bCount_is_outlier                                 0
# bMinPrice_is_outlier                              0
# bMaxPrice_is_outlier                              0
# bSumPrice_is_outlier                              0
# bStep_is_outlier                                  0
# maxVal_is_outlier                                 0
# customerScore_is_outlier                          0
# accountLifetime_is_outlier                        0
# payments_is_outlier                               0
# age_is_outlier                                    0
# lastOrder_is_outlier                              0
# time_of_day                                 morning
# availability_-99                                1.0
# availability_completely_not_determinable        0.0
# availability_completely_not_orderable           0.0
# availability_completely_orderable               0.0
# availability_mainly_not_determinable            0.0
# availability_mainly_not_orderable               0.0
# availability_mainly_orderable                   0.0
# address_-99                                     0.0
# address_1                                       1.0
# address_2                                       0.0
# time_of_day_afternoon                           0.0
# time_of_day_early_morning                       0.0
# time_of_day_evening                             0.0
# onlineStatus_-99                                1.0
# onlineStatus_0                                  0.0
# Name: 0, dtype: object

# %%
SAVE_DATA = False
FILE_NAME = 'iteration-2.csv'

if SAVE_DATA:
    output_train_path = os.path.join(
        '..',
        'dataset',
        'feature-engineering',
        FILE_NAME
    )
    df_train.to_csv(output_train_path, index=False)
