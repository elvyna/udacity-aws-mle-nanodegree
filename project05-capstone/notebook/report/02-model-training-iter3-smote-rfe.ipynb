# %% [markdown]
# # Notes
#
# Similar feature sets as iteration 1, except that we remove records that are considered as outliers at least in one column.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import os

sns.set_context('talk')

RND = 121

# %%
FILE_NAME = "df_train_rfe.csv"

input_train_path = os.path.join(
    '..',
    '..',
    'dataset',
    'feature-engineering',
    FILE_NAME
)

df_train = pd.read_csv(input_train_path)
df_train.head()

input_test_path = os.path.join(
    '..',
    '..',
    'dataset',
    'feature-engineering',
    FILE_NAME.replace('train','test')
)
df_test = pd.read_csv(input_test_path)
df_test.head()
# Out:
#    startHour  startWeekday  duration  cCount  cMinPrice  cMaxPrice  cSumPrice  \
# 0        6.0           6.0   148.694    14.0      11.99      26.99     261.88
# 1       21.0           5.0   502.445    15.0      29.99      49.99     629.85
# 2       21.0           6.0  2268.294    33.0       4.99      19.99     373.76
# 3        9.0           6.0    98.096     5.0      19.99      34.99     129.95
# 4        8.0           7.0   548.471     6.0       9.99      39.99     119.95
#
#    bCount  bMinPrice  bMaxPrice  ...  payments   age  lastOrder  \
# 0     3.0      11.99      26.99  ...     -99.0 -99.0      -99.0
# 1     4.0      29.99      49.99  ...       4.0  60.0       13.0
# 2     5.0       5.00      17.99  ...       1.0  55.0      230.0
# 3     5.0      19.99      34.99  ...       0.0  51.0      552.0
# 4     4.0       9.99      39.99  ...      88.0  41.0        5.0
#
#    availability_completely_orderable  address_1  address_2  \
# 0                                  0          0          0
# 1                                  1          0          1
# 2                                  1          0          1
# 3                                  1          0          1
# 4                                  0          1          0
#
#    time_of_day_afternoon  time_of_day_evening  onlineStatus_-99  order
# 0                      0                    0                 1      1
# 1                      0                    1                 0      1
# 2                      0                    1                 0      1
# 3                      0                    0                 0      1
# 4                      0                    0                 1      1
#
# [5 rows x 25 columns]

# %% [markdown]
# # Prepare training and test set

# %%
row_count = df_train.shape[0]
row_count
# Out:
# 238878

# %%
df_train.iloc[0]
# Out:
# startHour                              16.000
# startWeekday                            5.000
# duration                               84.495
# cCount                                  7.000
# cMinPrice                               3.990
# cMaxPrice                              29.990
# cSumPrice                             183.930
# bCount                                  1.000
# bMinPrice                              29.990
# bMaxPrice                              29.990
# bSumPrice                              29.990
# bStep                                 -99.000
# maxVal                               2500.000
# customerScore                         582.000
# accountLifetime                       359.000
# payments                               13.000
# age                                    72.000
# lastOrder                             146.000
# availability_completely_orderable       0.000
# address_1                               1.000
# address_2                               0.000
# time_of_day_afternoon                   1.000
# time_of_day_evening                     0.000
# onlineStatus_-99                        1.000
# order                                   1.000
# Name: 0, dtype: float64

# %%
categorical_feature_list_initial = [
    'availability_-99', 'availability_completely_not_determinable',
    'availability_completely_not_orderable','availability_completely_orderable',
    'availability_mainly_not_determinable','availability_mainly_not_orderable', 
    'availability_mainly_orderable',
    'address_-99', 'address_1', 'address_2', 
    'time_of_day_afternoon','time_of_day_early_morning', 'time_of_day_evening', 
    'onlineStatus_-99','onlineStatus_0'
]

categorical_feature_list = []
for col in categorical_feature_list_initial:
    try:
        df_train[col] = df_train[col].astype(int)
        df_test[col] = df_test[col].astype(int)
        categorical_feature_list.append(col)
    except:
        print(f"{col} doesn't exist!")
        continue
# Out:
# availability_-99 doesn't exist!
# availability_completely_not_determinable doesn't exist!
# availability_completely_not_orderable doesn't exist!
# availability_mainly_not_determinable doesn't exist!
# availability_mainly_not_orderable doesn't exist!
# availability_mainly_orderable doesn't exist!
# address_-99 doesn't exist!
# time_of_day_early_morning doesn't exist!
# onlineStatus_0 doesn't exist!

# %%
target_class = 'order'

y_train = df_train[target_class].copy()
X_train = df_train.drop(labels=[target_class], axis=1)

y_test = df_test[target_class].copy()
X_test = df_test.drop(labels=[target_class], axis=1)

# %%
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (238878, 24) (238878,)
# (128704, 24) (128704,)

# %%
from sklearn.metrics import accuracy_score, classification_report, f1_score
from sklearn.metrics import roc_auc_score

def evaluate_performance(y_true, y_pred, print_results = True):
    accuracy = accuracy_score(y_true, y_pred)
    f_score = f1_score(y_true, y_pred)
    auc = roc_auc_score(y_true, y_pred)
    
    if print_results:
        print(f"Accuracy : {accuracy:.3%}")
        print(f"F1-score : {f_score:.3%}")
        print(f"AUC: {auc:.3f}")
        print(classification_report(y_true, y_pred))
        
    return accuracy, f_score, auc

# %%
from sklearn.model_selection import KFold

def kfold_cv(clf, X_train, y_train, k = 10):
    kfold = KFold(random_state = RND, shuffle = True, n_splits = k)
    
    cv_accuracy = np.zeros(shape=k)
    cv_f1 = np.zeros(shape=k)
    cv_auc = np.zeros(shape=k)
    
    i = 0
    for train_index, val_index in kfold.split(X_train):
        X_tr = X_train.loc[train_index]
        y_tr = y_train.loc[train_index]
        X_val = X_train.loc[val_index]
        y_val = y_train.loc[val_index]
        
        clf.fit(X_tr, y_tr)
        y_pred = clf.predict(X_val)
        accuracy, f_score, auc = evaluate_performance(y_val, y_pred, print_results = False)
        print(f"Iteration {i+1}: Accuracy={accuracy:.3%} | F1-score={f_score:.3%} | AUC={auc:.3f}")
        
        cv_accuracy[i] = accuracy
        cv_f1[i] = f_score
        cv_auc[i] = auc
        
        i += 1
    
    print("Cross-validation results")
    print("========================")
    print(f"Accuracy: {np.mean(cv_accuracy):.3%} +- {np.std(cv_accuracy):.3%}")
    print(f"F1-score: {np.mean(cv_f1):.3%} +- {np.std(cv_f1):.3%}")
    print(f"AUC: {np.mean(cv_auc):.3f} +- {np.std(cv_auc):.3f}")

# %% [markdown]
# # Model Training and Evaluation
#
# ## Baseline: Logistic Regression without fine-tuning

# %%
from sklearn.linear_model import LogisticRegression

model_logres = LogisticRegression(random_state=RND, max_iter=200, solver='saga', penalty='elasticnet', l1_ratio=0.2)

## Perform k-fold cross-validation
KFOLD_ITER = 5
kfold_cv(model_logres, X_train, y_train, k=KFOLD_ITER)

## Train with the whole training set
model_logres.fit(X_train, y_train)
# Out:
# /home/elvyna/miniconda3/envs/py37/lib/python3.7/site-packages/sklearn/linear_model/_sag.py:329: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# Iteration 1: Accuracy=67.674% | F1-score=68.902% | AUC=0.677
# /home/elvyna/miniconda3/envs/py37/lib/python3.7/site-packages/sklearn/linear_model/_sag.py:329: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# Iteration 2: Accuracy=67.902% | F1-score=69.310% | AUC=0.679
# /home/elvyna/miniconda3/envs/py37/lib/python3.7/site-packages/sklearn/linear_model/_sag.py:329: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# Iteration 3: Accuracy=67.605% | F1-score=69.002% | AUC=0.676
# /home/elvyna/miniconda3/envs/py37/lib/python3.7/site-packages/sklearn/linear_model/_sag.py:329: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# Iteration 4: Accuracy=67.508% | F1-score=68.983% | AUC=0.675
# /home/elvyna/miniconda3/envs/py37/lib/python3.7/site-packages/sklearn/linear_model/_sag.py:329: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# Iteration 5: Accuracy=67.755% | F1-score=68.947% | AUC=0.678
# Cross-validation results
# ========================
# Accuracy: 67.689% +- 0.134%
# F1-score: 69.029% +- 0.145%
# AUC: 0.677 +- 0.001
# /home/elvyna/miniconda3/envs/py37/lib/python3.7/site-packages/sklearn/linear_model/_sag.py:329: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# LogisticRegression(l1_ratio=0.2, max_iter=200, penalty='elasticnet',
#                    random_state=121, solver='saga')

# %%
y_pred = model_logres.predict(X_test)
accuracy, f_score, auc = evaluate_performance(y_test, y_pred)
# Out:
# Accuracy : 68.326%
# F1-score : 75.566%
# AUC: 0.660
#               precision    recall  f1-score   support
#
#            0       0.51      0.59      0.55     41947
#            1       0.79      0.73      0.76     86757
#
#     accuracy                           0.68    128704
#    macro avg       0.65      0.66      0.65    128704
# weighted avg       0.70      0.68      0.69    128704

# %%
logres_coef = pd.DataFrame(
    data = {
        'feature_name': X_train.columns,
        'coef': model_logres.coef_[0]
    }
).sort_values(by='coef', ascending=False)
logres_coef['coef_abs'] = np.abs(logres_coef['coef'])


f, ax = plt.subplots(figsize=(12, 12))
sns.barplot(
    data=logres_coef,
    y='feature_name',
    x='coef',
    orient='h',
    palette='magma',
    ax=ax
);

plt.xlabel('coefficient value')
plt.ylabel('')
sns.despine();

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

model_rf = RandomForestClassifier(random_state=RND)

## Perform k-fold cross-validation
KFOLD_ITER = 5
kfold_cv(model_rf, X_train, y_train, k=KFOLD_ITER)

## Train with the whole training set
model_rf.fit(X_train, y_train)
# Out:
# Iteration 1: Accuracy=91.912% | F1-score=91.987% | AUC=0.919
# Iteration 2: Accuracy=91.826% | F1-score=92.008% | AUC=0.918
# Iteration 3: Accuracy=91.835% | F1-score=91.996% | AUC=0.918
# Iteration 4: Accuracy=91.847% | F1-score=92.001% | AUC=0.918
# Iteration 5: Accuracy=92.006% | F1-score=92.109% | AUC=0.920
# Cross-validation results
# ========================
# Accuracy: 91.885% +- 0.068%
# F1-score: 92.020% +- 0.045%
# AUC: 0.919 +- 0.001
# RandomForestClassifier(random_state=121)

# %%
y_pred = model_rf.predict(X_test)
accuracy, f_score, auc = evaluate_performance(y_test, y_pred)
# Out:
# Accuracy : 82.347%
# F1-score : 87.415%
# AUC: 0.778
#               precision    recall  f1-score   support
#
#            0       0.78      0.65      0.70     41947
#            1       0.84      0.91      0.87     86757
#
#     accuracy                           0.82    128704
#    macro avg       0.81      0.78      0.79    128704
# weighted avg       0.82      0.82      0.82    128704

# %%
model_rf.get_params()
# Out:
# {'bootstrap': True,
#  'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': None,
#  'max_features': 'auto',
#  'max_leaf_nodes': None,
#  'max_samples': None,
#  'min_impurity_decrease': 0.0,
#  'min_impurity_split': None,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'n_estimators': 100,
#  'n_jobs': None,
#  'oob_score': False,
#  'random_state': 121,
#  'verbose': 0,
#  'warm_start': False}

# %%
rf_coef = pd.DataFrame(
    data = {
        'feature_name': X_train.columns,
        'coef': model_rf.feature_importances_
    }
).sort_values(by='coef', ascending=False)
rf_coef['coef_abs'] = np.abs(rf_coef['coef'])


f, ax = plt.subplots(figsize=(12, 12))
sns.barplot(
    data=rf_coef,
    y='feature_name',
    x='coef',
    orient='h',
    palette='magma',
    ax=ax
);

plt.xlabel('coefficient value')
plt.ylabel('')
sns.despine();

# %% [markdown]
# # LightGBM

# %%
categorical_feature_list
# Out:
# ['availability_completely_orderable',
#  'address_1',
#  'address_2',
#  'time_of_day_afternoon',
#  'time_of_day_evening',
#  'onlineStatus_-99']

# %%
import lightgbm as lgbm

model_lgbm = lgbm.LGBMClassifier(
    random_state=RND,
    objective='binary',
    learning_rate=0.2,
    subsample=0.7,
    subsample_freq=3,
    colsample_bytree=0.8,
    reg_alpha=0.1,
    reg_lambda=0.1,
)

## Perform k-fold cross-validation
KFOLD_ITER = 5
kfold_cv(model_lgbm, X_train, y_train, k=KFOLD_ITER)

## Train with the whole training set
model_lgbm.fit(X_train, y_train, categorical_feature=categorical_feature_list)
# Out:
# Iteration 1: Accuracy=84.697% | F1-score=85.350% | AUC=0.847
# Iteration 2: Accuracy=84.890% | F1-score=85.660% | AUC=0.849
# Iteration 3: Accuracy=84.789% | F1-score=85.547% | AUC=0.848
# Iteration 4: Accuracy=84.651% | F1-score=85.416% | AUC=0.846
# Iteration 5: Accuracy=85.042% | F1-score=85.721% | AUC=0.851
# Cross-validation results
# ========================
# Accuracy: 84.814% +- 0.141%
# F1-score: 85.539% +- 0.140%
# AUC: 0.848 +- 0.002
# /home/elvyna/miniconda3/envs/py37/lib/python3.7/site-packages/lightgbm/basic.py:1551: UserWarning: Using categorical_feature in Dataset.
#   warnings.warn('Using categorical_feature in Dataset.')
# LGBMClassifier(colsample_bytree=0.8, learning_rate=0.2, objective='binary',
#                random_state=121, reg_alpha=0.1, reg_lambda=0.1, subsample=0.7,
#                subsample_freq=3)

# %%
model_lgbm.get_params()
# Out:
# {'boosting_type': 'gbdt',
#  'class_weight': None,
#  'colsample_bytree': 0.8,
#  'importance_type': 'split',
#  'learning_rate': 0.2,
#  'max_depth': -1,
#  'min_child_samples': 20,
#  'min_child_weight': 0.001,
#  'min_split_gain': 0.0,
#  'n_estimators': 100,
#  'n_jobs': -1,
#  'num_leaves': 31,
#  'objective': 'binary',
#  'random_state': 121,
#  'reg_alpha': 0.1,
#  'reg_lambda': 0.1,
#  'silent': True,
#  'subsample': 0.7,
#  'subsample_for_bin': 200000,
#  'subsample_freq': 3}

# %%
y_pred = model_lgbm.predict(X_test)
accuracy, f_score, auc = evaluate_performance(y_test, y_pred)
# Out:
# Accuracy : 76.237%
# F1-score : 83.402%
# AUC: 0.696
#               precision    recall  f1-score   support
#
#            0       0.68      0.51      0.58     41947
#            1       0.79      0.89      0.83     86757
#
#     accuracy                           0.76    128704
#    macro avg       0.74      0.70      0.71    128704
# weighted avg       0.75      0.76      0.75    128704

# %%
lgbm_coef = pd.DataFrame(
    data = {
        'feature_name': X_train.columns,
        'coef': model_lgbm.feature_importances_
    }
).sort_values(by='coef', ascending=False)
lgbm_coef['coef_abs'] = np.abs(lgbm_coef['coef'])


f, ax = plt.subplots(figsize=(12, 12))
sns.barplot(
    data=lgbm_coef,
    y='feature_name',
    x='coef',
    orient='h',
    palette='magma',
    ax=ax
);

plt.xlabel('coefficient value')
plt.ylabel('')
sns.despine();

# %% [markdown]
# # Catboost

# %%
from catboost import CatBoostClassifier

## https://catboost.ai/en/docs/concepts/parameter-tuning
model_catboost = CatBoostClassifier(
    iterations=100,
    learning_rate=0.2,
    max_depth=10,
    l2_leaf_reg=0.1,
    random_state=RND
)

## Perform k-fold cross-validation
KFOLD_ITER = 5
kfold_cv(model_catboost, X_train, y_train, k=KFOLD_ITER)

## Fit model
model_catboost.fit(X_train, y_train, cat_features=categorical_feature_list)
# # Get predicted classes
# preds_class = model_catboost.predict(eval_data)
# # Get predicted probabilities for each class
# preds_proba = model_catboost.predict_proba(eval_data)
# # Get predicted RawFormulaVal
# preds_raw = model_catboost.predict(eval_data, prediction_type='RawFormulaVal')
# Out:
# 0:	learn: 0.5945525	total: 359ms	remaining: 35.6s
# 1:	learn: 0.5037829	total: 593ms	remaining: 29.1s
# 2:	learn: 0.4726902	total: 864ms	remaining: 28s
# 3:	learn: 0.4467334	total: 1.01s	remaining: 24.2s
# 4:	learn: 0.4269674	total: 1.23s	remaining: 23.4s
# 47:	learn: 0.3020972	total: 7.97s	remaining: 8.64s
# 48:	learn: 0.3005723	total: 8.13s	remaining: 8.46s
# 49:	learn: 0.2983035	total: 8.32s	remaining: 8.32s
# 50:	learn: 0.2966887	total: 8.48s	remaining: 8.15s
# 51:	learn: 0.2947005	total: 8.75s	remaining: 8.08s
# 52:	learn: 0.2928413	total: 8.91s	remaining: 7.9s
# 53:	learn: 0.2914974	total: 9.1s	remaining: 7.75s
# 54:	learn: 0.2905660	total: 9.3s	remaining: 7.61s
# 55:	learn: 0.2896892	total: 9.52s	remaining: 7.48s
# 56:	learn: 0.2872796	total: 9.76s	remaining: 7.36s
# 57:	learn: 0.2859618	total: 10s	remaining: 7.24s
# 58:	learn: 0.2846550	total: 10.2s	remaining: 7.11s
# 59:	learn: 0.2828584	total: 10.4s	remaining: 6.95s
# 60:	learn: 0.2804932	total: 10.6s	remaining: 6.77s
# 61:	learn: 0.2797138	total: 10.7s	remaining: 6.57s
# 62:	learn: 0.2778101	total: 11s	remaining: 6.45s
# 63:	learn: 0.2762044	total: 11.1s	remaining: 6.26s
# 64:	learn: 0.2750371	total: 11.3s	remaining: 6.08s
# 65:	learn: 0.2732598	total: 11.5s	remaining: 5.93s
# 66:	learn: 0.2725131	total: 11.7s	remaining: 5.75s
# 67:	learn: 0.2716899	total: 11.9s	remaining: 5.6s
# 68:	learn: 0.2705693	total: 12.1s	remaining: 5.44s
# 69:	learn: 0.2697248	total: 12.3s	remaining: 5.28s
# 70:	learn: 0.2684720	total: 12.5s	remaining: 5.12s
# 71:	learn: 0.2663442	total: 12.9s	remaining: 5.01s
# 72:	learn: 0.2649621	total: 13.1s	remaining: 4.86s
# 73:	learn: 0.2641610	total: 13.2s	remaining: 4.65s
# 74:	learn: 0.2632654	total: 13.3s	remaining: 4.45s
# 75:	learn: 0.2620300	total: 13.5s	remaining: 4.26s
# 76:	learn: 0.2613646	total: 13.7s	remaining: 4.08s
# 77:	learn: 0.2602284	total: 13.8s	remaining: 3.89s
# 78:	learn: 0.2591119	total: 13.9s	remaining: 3.7s
# 79:	learn: 0.2581529	total: 14.1s	remaining: 3.52s
# 80:	learn: 0.2563670	total: 14.2s	remaining: 3.34s
# 81:	learn: 0.2552930	total: 14.4s	remaining: 3.16s
# 82:	learn: 0.2541688	total: 14.5s	remaining: 2.97s
# 83:	learn: 0.2533711	total: 14.6s	remaining: 2.79s
# 84:	learn: 0.2521497	total: 14.8s	remaining: 2.6s
# 85:	learn: 0.2510347	total: 14.9s	remaining: 2.43s
# 86:	learn: 0.2493488	total: 15.1s	remaining: 2.25s
# 87:	learn: 0.2482255	total: 15.2s	remaining: 2.08s
# 88:	learn: 0.2466262	total: 15.3s	remaining: 1.9s
# 89:	learn: 0.2454480	total: 15.5s	remaining: 1.73s
# 90:	learn: 0.2441985	total: 15.7s	remaining: 1.55s
# 91:	learn: 0.2424861	total: 15.8s	remaining: 1.38s
# 92:	learn: 0.2415700	total: 15.9s	remaining: 1.2s
# 93:	learn: 0.2406231	total: 16s	remaining: 1.02s
# 88:	learn: 0.2482633	total: 10.7s	remaining: 1.32s
# 89:	learn: 0.2472499	total: 10.9s	remaining: 1.21s
# 90:	learn: 0.2459985	total: 11s	remaining: 1.09s
# 91:	learn: 0.2453828	total: 11.2s	remaining: 970ms
# 92:	learn: 0.2440076	total: 11.3s	remaining: 850ms
# 93:	learn: 0.2424420	total: 11.4s	remaining: 729ms
# 94:	learn: 0.2409553	total: 11.6s	remaining: 608ms
# 95:	learn: 0.2397493	total: 11.7s	remaining: 487ms
# 96:	learn: 0.2389327	total: 11.8s	remaining: 366ms
# 97:	learn: 0.2379608	total: 12s	remaining: 244ms
# 98:	learn: 0.2371718	total: 12.1s	remaining: 122ms
# 99:	learn: 0.2357075	total: 12.2s	remaining: 0us
# Iteration 3: Accuracy=87.896% | F1-score=88.318% | AUC=0.879
# 0:	learn: 0.5945087	total: 183ms	remaining: 18.1s
# 1:	learn: 0.5033921	total: 315ms	remaining: 15.4s
# 2:	learn: 0.4713526	total: 448ms	remaining: 14.5s
# 3:	learn: 0.4468078	total: 587ms	remaining: 14.1s
# 4:	learn: 0.4306499	total: 716ms	remaining: 13.6s
# 5:	learn: 0.4132122	total: 861ms	remaining: 13.5s
# 6:	learn: 0.4013203	total: 1.01s	remaining: 13.4s
# 7:	learn: 0.3935512	total: 1.12s	remaining: 12.9s
# 8:	learn: 0.3897107	total: 1.25s	remaining: 12.6s
# 9:	learn: 0.3847109	total: 1.4s	remaining: 12.6s
# 10:	learn: 0.3804729	total: 1.53s	remaining: 12.4s
# 11:	learn: 0.3769696	total: 1.68s	remaining: 12.3s
# 12:	learn: 0.3742937	total: 1.82s	remaining: 12.2s
# 13:	learn: 0.3724549	total: 1.95s	remaining: 12s
# 14:	learn: 0.3706568	total: 2.07s	remaining: 11.7s
# 15:	learn: 0.3681537	total: 2.2s	remaining: 11.6s
# 16:	learn: 0.3657860	total: 2.33s	remaining: 11.4s
# 17:	learn: 0.3631574	total: 2.46s	remaining: 11.2s
# 18:	learn: 0.3613662	total: 2.59s	remaining: 11.1s
# 19:	learn: 0.3595247	total: 2.71s	remaining: 10.8s
# 20:	learn: 0.3574757	total: 2.86s	remaining: 10.7s
# 21:	learn: 0.3540570	total: 2.99s	remaining: 10.6s
# 22:	learn: 0.3520725	total: 3.11s	remaining: 10.4s
# 23:	learn: 0.3495818	total: 3.24s	remaining: 10.2s
# 24:	learn: 0.3454889	total: 3.37s	remaining: 10.1s
# 25:	learn: 0.3421519	total: 3.51s	remaining: 9.99s
# 26:	learn: 0.3401249	total: 3.7s	remaining: 10s
# 27:	learn: 0.3383362	total: 3.87s	remaining: 9.96s
# 28:	learn: 0.3362620	total: 4s	remaining: 9.8s
# 29:	learn: 0.3332932	total: 4.14s	remaining: 9.66s
# 30:	learn: 0.3313932	total: 4.26s	remaining: 9.49s
# 31:	learn: 0.3294872	total: 4.41s	remaining: 9.37s
# 32:	learn: 0.3274226	total: 4.61s	remaining: 9.36s
# 33:	learn: 0.3258584	total: 4.81s	remaining: 9.33s
# 34:	learn: 0.3231640	total: 4.91s	remaining: 9.12s
# 35:	learn: 0.3213795	total: 5s	remaining: 8.89s
# 36:	learn: 0.3185383	total: 5.1s	remaining: 8.68s
# 37:	learn: 0.3167784	total: 5.19s	remaining: 8.47s
# 38:	learn: 0.3150604	total: 5.29s	remaining: 8.27s
# 39:	learn: 0.3117882	total: 5.43s	remaining: 8.15s
# 40:	learn: 0.3098291	total: 5.61s	remaining: 8.08s
# 41:	learn: 0.3077782	total: 5.83s	remaining: 8.05s
# 42:	learn: 0.3067359	total: 5.99s	remaining: 7.94s
# 43:	learn: 0.3055424	total: 6.25s	remaining: 7.96s
# 44:	learn: 0.3033961	total: 6.38s	remaining: 7.79s
# 45:	learn: 0.3008669	total: 6.49s	remaining: 7.62s
# 46:	learn: 0.2994670	total: 6.6s	remaining: 7.45s
# 47:	learn: 0.2978276	total: 6.72s	remaining: 7.29s
# 48:	learn: 0.2965126	total: 6.86s	remaining: 7.14s
# 49:	learn: 0.2956015	total: 6.97s	remaining: 6.97s
# 50:	learn: 0.2942407	total: 7.08s	remaining: 6.8s
# 51:	learn: 0.2924073	total: 7.2s	remaining: 6.64s
# 52:	learn: 0.2903053	total: 7.31s	remaining: 6.48s
# 53:	learn: 0.2886161	total: 7.42s	remaining: 6.32s
# 54:	learn: 0.2861787	total: 7.53s	remaining: 6.16s
# 55:	learn: 0.2847458	total: 7.7s	remaining: 6.05s
# 56:	learn: 0.2838215	total: 7.87s	remaining: 5.94s
# 57:	learn: 0.2819541	total: 8.03s	remaining: 5.82s
# 58:	learn: 0.2808509	total: 8.14s	remaining: 5.66s
# 59:	learn: 0.2799635	total: 8.26s	remaining: 5.5s
# 60:	learn: 0.2786960	total: 8.37s	remaining: 5.35s
# 61:	learn: 0.2773456	total: 8.49s	remaining: 5.2s
# 62:	learn: 0.2759372	total: 8.6s	remaining: 5.05s
# 63:	learn: 0.2750460	total: 8.73s	remaining: 4.91s
# 64:	learn: 0.2735696	total: 8.86s	remaining: 4.77s
# 65:	learn: 0.2717941	total: 9.07s	remaining: 4.67s
# 66:	learn: 0.2703922	total: 9.18s	remaining: 4.52s
# 67:	learn: 0.2686814	total: 9.38s	remaining: 4.41s
# 68:	learn: 0.2676926	total: 9.57s	remaining: 4.3s
# 69:	learn: 0.2664305	total: 9.74s	remaining: 4.17s
# 70:	learn: 0.2653978	total: 9.9s	remaining: 4.04s
# 71:	learn: 0.2641888	total: 10.1s	remaining: 3.91s
# 72:	learn: 0.2632097	total: 10.2s	remaining: 3.77s
# 73:	learn: 0.2621124	total: 10.3s	remaining: 3.64s
# 74:	learn: 0.2607470	total: 10.5s	remaining: 3.5s
# 75:	learn: 0.2594721	total: 10.7s	remaining: 3.36s
# 76:	learn: 0.2587023	total: 10.8s	remaining: 3.22s
# 77:	learn: 0.2576778	total: 11s	remaining: 3.1s
# 78:	learn: 0.2569729	total: 11.2s	remaining: 2.97s
# 79:	learn: 0.2558770	total: 11.4s	remaining: 2.85s
# 80:	learn: 0.2545978	total: 11.6s	remaining: 2.72s
# 81:	learn: 0.2535436	total: 11.8s	remaining: 2.58s
# 82:	learn: 0.2523828	total: 11.9s	remaining: 2.44s
# 83:	learn: 0.2509456	total: 12.1s	remaining: 2.3s
# 84:	learn: 0.2497122	total: 12.2s	remaining: 2.16s
# 85:	learn: 0.2481510	total: 12.4s	remaining: 2.01s
# 86:	learn: 0.2474791	total: 12.5s	remaining: 1.86s
# 87:	learn: 0.2462109	total: 12.6s	remaining: 1.72s
# 88:	learn: 0.2456016	total: 12.8s	remaining: 1.58s
# 89:	learn: 0.2443845	total: 12.9s	remaining: 1.44s
# 90:	learn: 0.2429483	total: 13s	remaining: 1.29s
# 91:	learn: 0.2417971	total: 13.2s	remaining: 1.14s
# 92:	learn: 0.2409392	total: 13.3s	remaining: 999ms
# 93:	learn: 0.2397505	total: 13.4s	remaining: 855ms
# 94:	learn: 0.2390089	total: 13.5s	remaining: 710ms
# 95:	learn: 0.2383735	total: 13.6s	remaining: 567ms
# 96:	learn: 0.2375645	total: 13.7s	remaining: 424ms
# 97:	learn: 0.2365103	total: 13.9s	remaining: 283ms
# 98:	learn: 0.2353863	total: 14s	remaining: 141ms
# 99:	learn: 0.2345996	total: 14.2s	remaining: 0us
# Iteration 4: Accuracy=87.969% | F1-score=88.330% | AUC=0.880
# 0:	learn: 0.5952195	total: 192ms	remaining: 19s
# 1:	learn: 0.5046384	total: 337ms	remaining: 16.5s
# 2:	learn: 0.4722215	total: 472ms	remaining: 15.3s
# 3:	learn: 0.4500782	total: 615ms	remaining: 14.8s
# 4:	learn: 0.4286002	total: 796ms	remaining: 15.1s
# 5:	learn: 0.4095353	total: 936ms	remaining: 14.7s
# 6:	learn: 0.4029716	total: 1.12s	remaining: 14.9s
# 7:	learn: 0.3981345	total: 1.28s	remaining: 14.7s
# 8:	learn: 0.3922550	total: 1.49s	remaining: 15.1s
# 9:	learn: 0.3882796	total: 1.69s	remaining: 15.2s
# 10:	learn: 0.3851293	total: 1.86s	remaining: 15.1s
# 11:	learn: 0.3819128	total: 2.07s	remaining: 15.2s
# 12:	learn: 0.3793189	total: 2.26s	remaining: 15.1s
# 13:	learn: 0.3768172	total: 2.42s	remaining: 14.9s
# 14:	learn: 0.3745857	total: 2.57s	remaining: 14.6s
# 15:	learn: 0.3719503	total: 2.73s	remaining: 14.3s
# 16:	learn: 0.3680657	total: 2.88s	remaining: 14s
# 17:	learn: 0.3657630	total: 3.03s	remaining: 13.8s
# 18:	learn: 0.3624199	total: 3.17s	remaining: 13.5s
# 19:	learn: 0.3594616	total: 3.44s	remaining: 13.8s
# 20:	learn: 0.3578801	total: 3.59s	remaining: 13.5s
# 21:	learn: 0.3536616	total: 3.75s	remaining: 13.3s
# 22:	learn: 0.3482007	total: 3.94s	remaining: 13.2s
# 23:	learn: 0.3450295	total: 4.11s	remaining: 13s
# 24:	learn: 0.3431002	total: 4.32s	remaining: 12.9s
# 25:	learn: 0.3406799	total: 4.53s	remaining: 12.9s
# 26:	learn: 0.3388331	total: 4.83s	remaining: 13.1s
# 27:	learn: 0.3370579	total: 5.13s	remaining: 13.2s
# 28:	learn: 0.3352629	total: 5.38s	remaining: 13.2s
# 29:	learn: 0.3325771	total: 5.59s	remaining: 13s
# 30:	learn: 0.3301079	total: 5.83s	remaining: 13s
# 31:	learn: 0.3286577	total: 6.06s	remaining: 12.9s
# 32:	learn: 0.3254723	total: 6.36s	remaining: 12.9s
# 33:	learn: 0.3232077	total: 6.71s	remaining: 13s
# 34:	learn: 0.3219601	total: 7.12s	remaining: 13.2s
# 35:	learn: 0.3205061	total: 7.47s	remaining: 13.3s
# 36:	learn: 0.3175009	total: 7.71s	remaining: 13.1s
# 37:	learn: 0.3148794	total: 7.88s	remaining: 12.9s
# 38:	learn: 0.3131915	total: 8.08s	remaining: 12.6s
# 39:	learn: 0.3111229	total: 8.27s	remaining: 12.4s
# 40:	learn: 0.3084788	total: 8.4s	remaining: 12.1s
# 41:	learn: 0.3065852	total: 8.52s	remaining: 11.8s
# 42:	learn: 0.3051241	total: 8.62s	remaining: 11.4s
# 43:	learn: 0.3036842	total: 8.72s	remaining: 11.1s
# 44:	learn: 0.3017952	total: 8.83s	remaining: 10.8s
# 45:	learn: 0.3008841	total: 8.99s	remaining: 10.6s
# 46:	learn: 0.2996030	total: 9.13s	remaining: 10.3s
# 47:	learn: 0.2980935	total: 9.28s	remaining: 10.1s
# 48:	learn: 0.2965555	total: 9.43s	remaining: 9.81s
# 49:	learn: 0.2953870	total: 9.56s	remaining: 9.56s
# 50:	learn: 0.2938060	total: 9.69s	remaining: 9.31s
# 51:	learn: 0.2925384	total: 9.82s	remaining: 9.06s
# 52:	learn: 0.2913608	total: 10s	remaining: 8.88s
# 53:	learn: 0.2896003	total: 10.2s	remaining: 8.69s
# 54:	learn: 0.2887580	total: 10.4s	remaining: 8.53s
# 55:	learn: 0.2874278	total: 10.6s	remaining: 8.34s
# 56:	learn: 0.2858559	total: 10.8s	remaining: 8.14s
# 57:	learn: 0.2850556	total: 11.1s	remaining: 8s
# 58:	learn: 0.2834547	total: 11.3s	remaining: 7.83s
# 59:	learn: 0.2815495	total: 11.4s	remaining: 7.6s
# 60:	learn: 0.2800424	total: 11.6s	remaining: 7.4s
# 61:	learn: 0.2786272	total: 11.8s	remaining: 7.2s
# 62:	learn: 0.2773004	total: 12s	remaining: 7.06s
# 63:	learn: 0.2761832	total: 12.3s	remaining: 6.9s
# 64:	learn: 0.2754212	total: 12.6s	remaining: 6.77s
# 65:	learn: 0.2737371	total: 12.7s	remaining: 6.54s
# 66:	learn: 0.2720891	total: 12.8s	remaining: 6.32s
# 67:	learn: 0.2712022	total: 13s	remaining: 6.11s
# 68:	learn: 0.2697358	total: 13.2s	remaining: 5.93s
# 69:	learn: 0.2687011	total: 13.4s	remaining: 5.73s
# 70:	learn: 0.2668400	total: 13.5s	remaining: 5.51s
# 71:	learn: 0.2657278	total: 13.6s	remaining: 5.29s
# 72:	learn: 0.2652062	total: 13.7s	remaining: 5.07s
# 73:	learn: 0.2634752	total: 13.9s	remaining: 4.88s
# 74:	learn: 0.2619021	total: 14.1s	remaining: 4.71s
# 75:	learn: 0.2605591	total: 14.4s	remaining: 4.54s
# 76:	learn: 0.2586513	total: 14.6s	remaining: 4.37s
# 77:	learn: 0.2578927	total: 14.8s	remaining: 4.17s
# 78:	learn: 0.2562149	total: 15s	remaining: 3.98s
# 79:	learn: 0.2548126	total: 15.1s	remaining: 3.79s
# 80:	learn: 0.2539396	total: 15.3s	remaining: 3.59s
# 81:	learn: 0.2531228	total: 15.4s	remaining: 3.39s
# 82:	learn: 0.2523567	total: 15.6s	remaining: 3.19s
# 83:	learn: 0.2505968	total: 15.7s	remaining: 3s
# 84:	learn: 0.2498286	total: 15.9s	remaining: 2.81s
# 85:	learn: 0.2488378	total: 16.1s	remaining: 2.62s
# 86:	learn: 0.2476090	total: 16.2s	remaining: 2.43s
# 87:	learn: 0.2467457	total: 16.4s	remaining: 2.24s
# 88:	learn: 0.2454880	total: 16.6s	remaining: 2.05s
# 89:	learn: 0.2442588	total: 16.7s	remaining: 1.86s
# 90:	learn: 0.2431298	total: 16.9s	remaining: 1.68s
# 91:	learn: 0.2418666	total: 17.1s	remaining: 1.49s
# 92:	learn: 0.2406358	total: 17.4s	remaining: 1.31s
# 93:	learn: 0.2393387	total: 17.7s	remaining: 1.13s
# 94:	learn: 0.2381144	total: 17.9s	remaining: 944ms
# 95:	learn: 0.2368311	total: 18.2s	remaining: 758ms
# 96:	learn: 0.2357898	total: 18.4s	remaining: 569ms
# 97:	learn: 0.2343313	total: 18.6s	remaining: 380ms
# 98:	learn: 0.2330766	total: 18.8s	remaining: 190ms
# 99:	learn: 0.2318929	total: 19.1s	remaining: 0us
# Iteration 5: Accuracy=88.437% | F1-score=88.738% | AUC=0.885
# Cross-validation results
# ========================
# Accuracy: 88.143% +- 0.205%
# F1-score: 88.491% +- 0.190%
# AUC: 0.881 +- 0.002
# 0:	learn: 0.5835005	total: 377ms	remaining: 37.3s
# 1:	learn: 0.5224921	total: 643ms	remaining: 31.5s
# 2:	learn: 0.4659821	total: 904ms	remaining: 29.2s
# 3:	learn: 0.4458197	total: 1.11s	remaining: 26.8s
# 4:	learn: 0.4299013	total: 1.27s	remaining: 24.1s
# 5:	learn: 0.4121908	total: 1.4s	remaining: 21.9s
# 6:	learn: 0.4036021	total: 1.53s	remaining: 20.3s
# 7:	learn: 0.3983920	total: 1.66s	remaining: 19.1s
# 8:	learn: 0.3937456	total: 1.78s	remaining: 18s
# 9:	learn: 0.3894879	total: 1.91s	remaining: 17.2s
# 10:	learn: 0.3804234	total: 2.11s	remaining: 17.1s
# 11:	learn: 0.3768097	total: 2.28s	remaining: 16.7s
# 12:	learn: 0.3745132	total: 2.52s	remaining: 16.8s
# 13:	learn: 0.3695449	total: 2.71s	remaining: 16.7s
# 14:	learn: 0.3665716	total: 2.91s	remaining: 16.5s
# 15:	learn: 0.3643799	total: 3.08s	remaining: 16.2s
# 16:	learn: 0.3620110	total: 3.29s	remaining: 16s
# 17:	learn: 0.3587075	total: 3.41s	remaining: 15.5s
# 18:	learn: 0.3571499	total: 3.52s	remaining: 15s
# 19:	learn: 0.3540088	total: 3.63s	remaining: 14.5s
# 20:	learn: 0.3512428	total: 3.74s	remaining: 14.1s
# 21:	learn: 0.3484594	total: 3.88s	remaining: 13.7s
# 22:	learn: 0.3466911	total: 4s	remaining: 13.4s
# 23:	learn: 0.3452058	total: 4.12s	remaining: 13s
# 24:	learn: 0.3425042	total: 4.23s	remaining: 12.7s
# 25:	learn: 0.3407813	total: 4.33s	remaining: 12.3s
# 26:	learn: 0.3386626	total: 4.45s	remaining: 12s
# 27:	learn: 0.3368677	total: 4.56s	remaining: 11.7s
# 28:	learn: 0.3350335	total: 4.69s	remaining: 11.5s
# 29:	learn: 0.3316229	total: 4.8s	remaining: 11.2s
# 30:	learn: 0.3304126	total: 4.91s	remaining: 10.9s
# 31:	learn: 0.3281949	total: 5.12s	remaining: 10.9s
# 32:	learn: 0.3265377	total: 5.38s	remaining: 10.9s
# 33:	learn: 0.3239274	total: 5.64s	remaining: 10.9s
# 34:	learn: 0.3208661	total: 5.8s	remaining: 10.8s
# 35:	learn: 0.3194285	total: 5.93s	remaining: 10.5s
# 36:	learn: 0.3165818	total: 6.07s	remaining: 10.3s
# 37:	learn: 0.3155130	total: 6.2s	remaining: 10.1s
# 38:	learn: 0.3138340	total: 6.33s	remaining: 9.9s
# 39:	learn: 0.3123194	total: 6.45s	remaining: 9.67s
# 40:	learn: 0.3105780	total: 6.56s	remaining: 9.43s
# 41:	learn: 0.3081628	total: 6.77s	remaining: 9.35s
# 42:	learn: 0.3070862	total: 6.97s	remaining: 9.24s
# 43:	learn: 0.3053170	total: 7.23s	remaining: 9.2s
# 44:	learn: 0.3036622	total: 7.39s	remaining: 9.03s
# 45:	learn: 0.3018217	total: 7.51s	remaining: 8.81s
# 46:	learn: 0.3001287	total: 7.63s	remaining: 8.6s
# 47:	learn: 0.2983558	total: 7.81s	remaining: 8.46s
# 48:	learn: 0.2967802	total: 7.92s	remaining: 8.25s
# 49:	learn: 0.2950923	total: 8.04s	remaining: 8.04s
# 50:	learn: 0.2935335	total: 8.15s	remaining: 7.83s
# 51:	learn: 0.2919394	total: 8.27s	remaining: 7.63s
# 52:	learn: 0.2902206	total: 8.39s	remaining: 7.44s
# 53:	learn: 0.2887496	total: 8.52s	remaining: 7.26s
# 54:	learn: 0.2871170	total: 8.64s	remaining: 7.07s
# 55:	learn: 0.2862692	total: 8.76s	remaining: 6.88s
# 56:	learn: 0.2848791	total: 8.89s	remaining: 6.71s
# 57:	learn: 0.2835473	total: 9.02s	remaining: 6.53s
# 58:	learn: 0.2824346	total: 9.17s	remaining: 6.37s
# 59:	learn: 0.2808378	total: 9.42s	remaining: 6.28s
# 60:	learn: 0.2796875	total: 9.63s	remaining: 6.16s
# 61:	learn: 0.2785117	total: 9.77s	remaining: 5.99s
# 62:	learn: 0.2771824	total: 9.89s	remaining: 5.81s
# 63:	learn: 0.2763667	total: 10s	remaining: 5.64s
# 64:	learn: 0.2754120	total: 10.1s	remaining: 5.46s
# 65:	learn: 0.2737509	total: 10.3s	remaining: 5.33s
# 66:	learn: 0.2721216	total: 10.6s	remaining: 5.22s
# 67:	learn: 0.2705416	total: 10.8s	remaining: 5.07s
# 68:	learn: 0.2693646	total: 11s	remaining: 4.93s
# 69:	learn: 0.2687094	total: 11.2s	remaining: 4.79s
# 70:	learn: 0.2672373	total: 11.5s	remaining: 4.68s
# 71:	learn: 0.2656146	total: 11.7s	remaining: 4.55s
# 72:	learn: 0.2630264	total: 11.9s	remaining: 4.39s
# 73:	learn: 0.2615575	total: 12s	remaining: 4.21s
# 74:	learn: 0.2609467	total: 12.1s	remaining: 4.04s
# 75:	learn: 0.2598619	total: 12.2s	remaining: 3.86s
# 76:	learn: 0.2582046	total: 12.4s	remaining: 3.71s
# 77:	learn: 0.2570542	total: 12.6s	remaining: 3.56s
# 78:	learn: 0.2560056	total: 12.8s	remaining: 3.39s
# 79:	learn: 0.2549471	total: 12.9s	remaining: 3.23s
# 80:	learn: 0.2529765	total: 13s	remaining: 3.06s
# 81:	learn: 0.2517821	total: 13.2s	remaining: 2.91s
# 82:	learn: 0.2511013	total: 13.5s	remaining: 2.77s
# 83:	learn: 0.2496838	total: 13.9s	remaining: 2.65s
# 84:	learn: 0.2488659	total: 14.1s	remaining: 2.49s
# 85:	learn: 0.2475399	total: 14.5s	remaining: 2.36s
# 86:	learn: 0.2459984	total: 14.8s	remaining: 2.21s
# 87:	learn: 0.2448500	total: 15s	remaining: 2.05s
# 88:	learn: 0.2437295	total: 15.4s	remaining: 1.9s
# 89:	learn: 0.2422833	total: 15.6s	remaining: 1.74s
# 90:	learn: 0.2408022	total: 15.9s	remaining: 1.57s
# 91:	learn: 0.2401130	total: 16.1s	remaining: 1.4s
# 92:	learn: 0.2394177	total: 16.4s	remaining: 1.23s
# 93:	learn: 0.2383525	total: 16.6s	remaining: 1.06s
# 94:	learn: 0.2368604	total: 16.8s	remaining: 882ms
# 95:	learn: 0.2351487	total: 17s	remaining: 707ms
# 96:	learn: 0.2339322	total: 17.2s	remaining: 533ms
# 97:	learn: 0.2326988	total: 17.5s	remaining: 357ms
# 98:	learn: 0.2320811	total: 17.8s	remaining: 179ms
# 99:	learn: 0.2307051	total: 18.1s	remaining: 0us

# %%
model_catboost.get_params()
# Out:
# {'iterations': 100,
#  'learning_rate': 0.2,
#  'l2_leaf_reg': 0.1,
#  'max_depth': 10,
#  'random_state': 121}

# %%
y_pred = model_catboost.predict(X_test)
accuracy, f_score, auc = evaluate_performance(y_test, y_pred)
# Out:
# Accuracy : 78.657%
# F1-score : 84.883%
# AUC: 0.732
#               precision    recall  f1-score   support
#
#            0       0.71      0.57      0.64     41947
#            1       0.81      0.89      0.85     86757
#
#     accuracy                           0.79    128704
#    macro avg       0.76      0.73      0.74    128704
# weighted avg       0.78      0.79      0.78    128704

# %%
catboost_coef = pd.DataFrame(
    data = {
        'feature_name': X_train.columns,
        'coef': model_catboost.feature_importances_
    }
).sort_values(by='coef', ascending=False)
catboost_coef['coef_abs'] = np.abs(catboost_coef['coef'])


f, ax = plt.subplots(figsize=(12, 12))
sns.barplot(
    data=catboost_coef,
    y='feature_name',
    x='coef',
    orient='h',
    palette='magma',
    ax=ax
);

plt.xlabel('coefficient value')
plt.ylabel('')
sns.despine();
